# %%
# !pip install pillow
# !pip install face_recognition
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (7.1.2)
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from face_recognition) (1.19.5)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Collecting face-recognition-models>=0.3.0
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      |████████████████████████████████| 100.1 MB 26 kB/s
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (19.18.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566185 sha256=ae7c4d9dbdd2a6f0205858007c40122fc19943b8ab16a1dfe1335ecb2a8af0db
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %%
from PIL import Image, ImageDraw
import face_recognition

# %%
image_array = face_recognition.load_image_file("graduation.jpeg")
face_locations = face_recognition.face_locations(image_array)
face_locations
# Out:
# [(316, 513, 539, 291), (295, 151, 402, 44), (390, 282, 498, 175)]

# %%
image = Image.fromarray(image_array)
draw = ImageDraw.Draw(image)

# %%
for face_location in face_locations:
    top, right, bottom, left = face_location
    print(top,right,bottom,left)
    draw.rectangle(
        ((left, top), (right, bottom)), 
        outline=(50, 181, 201),
        width=5,
    )
    display(image)
# Out:
# 316 513 539 291
# <PIL.Image.Image image mode=RGB size=549x1024 at 0x7F7CBCA27310>
# 295 151 402 44
# <PIL.Image.Image image mode=RGB size=549x1024 at 0x7F7CBCA27310>
# 390 282 498 175
# <PIL.Image.Image image mode=RGB size=549x1024 at 0x7F7CBCA27310>

# %%
face_encodings = face_recognition.face_encodings(image_array, face_locations)

# %%
for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
  matches = face_recognition.compare_faces(face_encodings, face_encoding)
  print(matches)
# Out:
# [True, True, True]
# [True, True, True]
# [True, True, True]
