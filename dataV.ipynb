# %%
# !pip install facets-overview
# Out:
# Collecting facets-overview
#   Downloading facets_overview-1.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from facets-overview) (1.19.5)
# Requirement already satisfied: protobuf>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from facets-overview) (3.17.3)
# Requirement already satisfied: pandas>=0.22.0 in /usr/local/lib/python3.7/dist-packages (from facets-overview) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.22.0->facets-overview) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.22.0->facets-overview) (2.8.2)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.7.0->facets-overview) (1.15.0)
# Installing collected packages: facets-overview
# Successfully installed facets-overview-1.0.0

# %%
import pandas as pd
from IPython.core.display import display, HTML

# %%
train_data = pd.read_csv("X.csv")

# %%
train_data.head()
# Out:
#    bottom-lip       chin   left-eye  ...  right-eyebrow    top-lip  relationship?
# 0    5.352868   7.095823   8.990250  ...      20.673070  25.374005              1
# 1    7.409184   8.256398  10.018910  ...      18.768479  20.675140              1
# 2    5.768454  10.788414  19.033199  ...      44.326786  48.320574              1
# 3    6.044672   8.452578  11.627989  ...      22.776269  26.214217              1
# 4    2.334821   3.417664   3.817664  ...       9.588672  13.758332              1
#
# [5 rows x 10 columns]

# %%
jsonstr = train_data.to_json(orient='records')
HTML_TEMPLATE = """
<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
<link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
<facets-dive id="elem" height="600"></facets-dive>
<script>
var data = {jsonstr};
document.querySelector("#elem").data = data;
</script>"""
html = HTML_TEMPLATE.format(jsonstr=jsonstr)
display(HTML(html))
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
# <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
# <facets-dive id="elem" height="600"></facets-dive>
# <script>
# var data = [{"bottom-lip":5.3528675105,"chin":7.0958228389,"left-eye":8.9902500299,"left-eyebrow":10.4618374092,"nosebridge":12.6520063331,"nose-tip":14.6033736552,"right-eye":15.7414448427,"right-eyebrow":20.6730698853,"top-lip":25.3740050896,"relationship?":1},{"bottom-lip":7.4091843575,"chin":8.256397953,"left-eye":10.018909793,"left-eyebrow":12.5511573441,"nosebridge":13.5511573441,"nose-tip":15.1201929378,"right-eye":16.6309421215,"right-eyebrow":18.7684789105,"top-lip":20.6751403052,"relationship?":1},{"bottom-lip":5.7684544446,"chin":10.7884135648,"left-eye":19.0331988613,"left-eyebrow":25.0834637656,"nosebridge":29.1032676683,"nose-tip":32.3174982159,"right-eye":38.3174982159,"right-eyebrow":44.3267856959,"top-lip":48.320573668,"relationship?":1},{"bottom-lip":6.04467178,"chin":8.4525777152,"left-eye":11.6279885756,"left-eyebrow":14.7460225644,"nosebridge":16.4889778928,"nose-tip":17.7246801532,"right-eye":19.6663937432,"right-eyebrow":22.7762687581,"top-lip":26.214216858,"relationship?":1},{"bottom-lip":2.3348211064,"chin":3.4176638189,"left-eye":3.8176638189,"left-eyebrow":4.9212172095,"nosebridge":6.004059922,"nose-tip":6.8373932553,"right-eye":7.406428849,"right-eyebrow":9.5886715655,"top-lip":13.7583316734,"relationship?":1},{"bottom-lip":8.3178093714,"chin":11.084274179,"left-eye":12.9826543375,"left-eyebrow":14.3952247225,"nosebridge":16.278067435,"nose-tip":17.4161386224,"right-eye":18.7602211395,"right-eyebrow":23.1840373044,"top-lip":27.6450